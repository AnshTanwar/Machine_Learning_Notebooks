# %% [markdown]
# <a href="https://www.kaggle.com/code/anshtanwar/visualize-decision-trees-dtreeviz?scriptVersionId=138075885" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <div style="background-color:#fff1cc; padding: 30px;">
#
# <br>
# Dtreeviz is a python library for decision tree visualization and model interpretation. It currently supports scikit-learn, XGBoost, Spark MLlib, and LightGBM trees. It provides several features such as tree visualization, prediction path explanations, leaf information, feature space exploration, classification boundaries, and more.
# <br><br>
# **In this tutorial, we will use Dtreeviz to visualize decision trees for regression task . We will start by loading and exploring the dataset.**
#
# </div>

# %% [markdown]
# ![image.png](attachment:f6941b43-f6a1-44f0-a722-2ee1ee52c8f8.png)

# %% [markdown]
# ### Thanks for Visting this Notebook :)
# <div class="alert alert-block alert-info" style="font-size:20px; font-family:verdana;">
#     Feel free to fork or edit the notebook.If you liked the notebook please upvote and comment your valuable feedbacks. It helps other people discover them.
# </div>

# %%
# !pip install dtreeviz
# Out:
# Collecting dtreeviz
#   Downloading dtreeviz-2.2.2-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: graphviz>=0.9 in /opt/conda/lib/python3.10/site-packages (from dtreeviz) (0.20.1)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from dtreeviz) (1.5.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from dtreeviz) (1.23.5)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from dtreeviz) (1.2.2)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from dtreeviz) (3.7.1)
# Collecting colour (from dtreeviz)
#   Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: pytest in /opt/conda/lib/python3.10/site-packages (from dtreeviz) (7.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->dtreeviz) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->dtreeviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->dtreeviz) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->dtreeviz) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->dtreeviz) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->dtreeviz) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->dtreeviz) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->dtreeviz) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->dtreeviz) (2023.3)
# Requirement already satisfied: iniconfig in /opt/conda/lib/python3.10/site-packages (from pytest->dtreeviz) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /opt/conda/lib/python3.10/site-packages (from pytest->dtreeviz) (1.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /opt/conda/lib/python3.10/site-packages (from pytest->dtreeviz) (1.1.1)
# Requirement already satisfied: tomli>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from pytest->dtreeviz) (2.0.1)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->dtreeviz) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->dtreeviz) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->dtreeviz) (3.1.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->dtreeviz) (1.16.0)
# Installing collected packages: colour, dtreeviz
# Successfully installed colour-0.1.5 dtreeviz-2.2.2

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
import pandas as pd
import dtreeviz
# %config InlineBackend.figure_format = 'retina'
random_state = 1234 # get reproducible trees
import pandas as pd

#Loading Dataset
dataset_url = "https://raw.githubusercontent.com/parrt/dtreeviz/master/data/cars.csv"
df_cars = pd.read_csv(dataset_url)
X = df_cars.drop('MPG', axis=1)
y = df_cars['MPG']
features = list(X.columns)
x = df_cars[['CYL','ENG','WGT']].iloc[10]

#Training DecisionTreeRegressor Model
dtr_cars = DecisionTreeRegressor(max_depth=3, criterion="absolute_error")
dtr_cars.fit(X.values, y.values)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# DecisionTreeRegressor(criterion='absolute_error', max_depth=3)

# %%
#Initializing dtreeviz.model
viz_rmodel = dtreeviz.model(dtr_cars, X, y,
                            feature_names=features,
                            target_name='MPG')

# %% [markdown]
# # <div style="background-color:#fff1cc; padding: 20px;">Tree structure  </div>

# %%
viz_rmodel.view()

# %% [markdown]
# # <div style="background-color:#fff1cc; padding: 20px;">Prediction path </div>

# %%
viz_rmodel.view(x = x)

# %%
viz_rmodel.instance_feature_importance(x, figsize=(3.5,2))

# %% [markdown]
# # <div style="background-color:#fff1cc; padding: 20px;">Leaf info</div>

# %%
viz_rmodel.leaf_sizes(figsize=(3.5,2))

# %%
viz_rmodel.rtree_leaf_distributions()

# %%
viz_rmodel.leaf_purity(figsize=(3.5,2))

# %% [markdown]
# # <div style="background-color:#fff1cc; padding: 20px;">Regression</div>

# %%
viz_rmodel.rtree_feature_space(features=['WGT'])

# %%
viz_rmodel.rtree_feature_space3D(features=['WGT','ENG'],
                                 fontsize=10,
                                 elev=30, azim=20,
                                 show={'splits', 'title'},
                                 colors={'tessellation_alpha': .5})

# %%
viz_rmodel.rtree_feature_space(features=['WGT','ENG'])

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:30px; font-family:verdana;">
#     Feel free to fork or edit the notebook and Consider upvoting ,it helps other people discover them.
# </div>
